# %% [markdown]
# # Video Game Sales and Ratings
#
# ### Part 1 - Visualization
#
# Data Source: https://www.kaggle.com/rush4ratio/video-game-sales-with-ratings

# %%
# Import libraries and CSV
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
import math
import os

# %matplotlib inline
df = pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# 0          51.0          8       322.0  Nintendo      E
# 1           NaN        NaN         NaN       NaN    NaN
# 2          73.0        8.3       709.0  Nintendo      E
# 3          73.0          8       192.0  Nintendo      E
# 4           NaN        NaN         NaN       NaN    NaN

# %%
df.columns
# Out:
# Index(['Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
df = df[['Name','Platform','Year_of_Release','Genre', 'Publisher', 'NA_Sales','EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales','Developer', 'Rating']]

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Developer Rating
# 0     41.36     28.96      3.77         8.45         82.53  Nintendo      E
# 1     29.08      3.58      6.81         0.77         40.24       NaN    NaN
# 2     15.68     12.76      3.79         3.29         35.52  Nintendo      E
# 3     15.61     10.93      3.28         2.95         32.77  Nintendo      E
# 4     11.27      8.89     10.22         1.00         31.37       NaN    NaN

# %%
null_cols = df.isnull().sum()
null_cols
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Developer          6623
# Rating             6769
# dtype: int64

# %%
df['Publisher'] = np.where(df['Publisher'].isna()==True, df['Developer'], df['Publisher'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 12 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16674 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Developer          10096 non-null object
# Rating             9950 non-null object
# dtypes: float64(6), object(6)
# memory usage: 1.5+ MB

# %%
df.drop(['Developer'], axis=1, inplace=True)

# %%
df['Rating'].fillna('U', inplace=True)

# %%
df = df.rename(columns={'index':'rank'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 11 columns):
# Name               16717 non-null object
# Platform           16719 non-null object
# Year_of_Release    16450 non-null float64
# Genre              16717 non-null object
# Publisher          16674 non-null object
# NA_Sales           16719 non-null float64
# EU_Sales           16719 non-null float64
# JP_Sales           16719 non-null float64
# Other_Sales        16719 non-null float64
# Global_Sales       16719 non-null float64
# Rating             16719 non-null object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
df = df.dropna()

# %%
df.reset_index(inplace=True)

# %%
df = df.rename(columns={'index':'rank'})

# %%
df['rank'] = df['rank'].apply(lambda x: x+1)

# %%
df['Year_of_Release'] = df['Year_of_Release'].astype(int)

# %%
df.head()
# Out:
#    rank                      Name Platform  Year_of_Release         Genre  \
# 0     1                Wii Sports      Wii             2006        Sports
# 1     2         Super Mario Bros.      NES             1985      Platform
# 2     3            Mario Kart Wii      Wii             2008        Racing
# 3     4         Wii Sports Resort      Wii             2009        Sports
# 4     5  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales Rating
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53      E
# 1  Nintendo     29.08      3.58      6.81         0.77         40.24      U
# 2  Nintendo     15.68     12.76      3.79         3.29         35.52      E
# 3  Nintendo     15.61     10.93      3.28         2.95         32.77      E
# 4  Nintendo     11.27      8.89     10.22         1.00         31.37      U

# %% [markdown]
# # Explore Sales Data

# %%
sns.set()

# %%
platGenre = pd.crosstab(df.Platform,df.Genre)
platGenreTotal = platGenre.sum(axis=1).sort_values(ascending = False)
platGenreTotal = platGenreTotal[platGenreTotal>50]

plt.figure(figsize=(16,7))
ax = sns.barplot(y = platGenreTotal.index, x = platGenreTotal.values, orient='h')

ax.set_xlabel(xlabel='Amount of Games Developed (Total)', fontsize=16)
ax.set_ylabel(ylabel="Genre", fontsize=16)
ax.set_title(label="Number of Games Sold Per Platform", fontsize=20)

plt.show()

# %%
platGenre['Total'] = platGenre.sum(axis=1)
platGenre.head()
# Out:
# Genre     Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# Platform
# 2600          55          1         1     5         9       8       4
# 3DO            0          1         0     0         0       1       0
# 3DS          187         37        14    54        28      20      10
# DC             3         11        12     0         2       0       6
# DS           333        236        36   387        89     234      66
#
# Genre     Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# Platform
# 2600                 0       22           1      10         0    116
# 3DO                  0        0           1       0         0      3
# 3DS                 87        6          29      25        15    512
# DC                   4        3           1      10         0     52
# DS                 196       42         279     146        78   2122

# %%
#Develop Heat Map
popPlatform = platGenre[platGenre['Total']>500].sort_values(by='Total', ascending = False)
neededdata = popPlatform.loc[:,:'Strategy']
maxi = neededdata.values.max()
mini = neededdata.values.min()
popPlatformfinal = popPlatform.append(pd.DataFrame(popPlatform.sum(), columns=['total']).T, ignore_index=False)

plt.figure(figsize=(17,8))
ax = sns.heatmap(popPlatformfinal, vmin = mini, vmax = maxi, annot=True, fmt="d")
ax.set_title(label="Platform vs. Genre", fontsize=20)
#plt.xticks(rotation = 90)
plt.show()

# %%
popPlatformfinal
# Out:
# Genre  Action  Adventure  Fighting  Misc  Platform  Puzzle  Racing  \
# PS2       345        196       146   218       101      18     212
# DS        333        236        36   387        89     234      66
# PS3       373         72        76   122        36       2      90
# Wii       229         82        41   272        57      54      91
# X360      317         48        65   123        25       6     101
# PSP       217        213        73   104        36      44      63
# PS        154         67       108    76        64      32     144
# PC        166         65         5    22        11      25      57
# XB        152         26        44    45        49       7     122
# GBA       162         36        23    86       139      39      64
# GC         98         20        42    35        73      12      60
# 3DS       187         37        14    54        28      20      10
# total    2733       1098       673  1544       708     493    1080
#
# Genre  Role-Playing  Shooter  Simulation  Sports  Strategy  Total
# PS2             183      158          89     391        70   2127
# DS              196       42         279     146        78   2122
# PS3             117      155          30     211        22   1306
# Wii              35       61          84     255        25   1286
# X360             75      197          36     212        27   1232
# PSP             191       37          28     129        58   1193
# PS               97       96          60     221        71   1190
# PC              103      147         119      50       185    955
# XB               23      124          24     166        21    803
# GBA              73       40          18      88        18    786
# GC               25       48          12     106        11    542
# 3DS              87        6          29      25        15    512
# total          1205     1111         808    2000       601  14054

# %%
platYearTotal = pd.crosstab(df.Genre,df['Year_of_Release'])
platYearTotal = platYearTotal.sum(axis=1).sort_values(ascending = False)
platYearTotal2 = platYearTotal[platYearTotal>50]

plt.figure(figsize=(16,8))
ax = sns.barplot(y = platYearTotal2.index, x = platYearTotal.values, orient='h')

ax.set_xlabel(xlabel='Amount of Games Developed (Total)', fontsize=16)
ax.set_ylabel(ylabel="Platform", fontsize=16)
ax.set_title(label="Number of Games Sold Per Platform", fontsize=20)

plt.show()

# %%
platYear['Total'] = platYear.sum(axis=1)
platYear
# Out:
# Year_of_Release  1980.0  1981.0  1982.0  1983.0  1984.0  1985.0  1986.0  \
# Platform
# 2600                  9      46      36      11       1       1       2
# 3DO                   0       0       0       0       0       0       0
# 3DS                   0       0       0       0       0       0       0
# DC                    0       0       0       0       0       0       0
# DS                    0       0       0       0       0       1       0
# GB                    0       0       0       0       0       0       0
# GBA                   0       0       0       0       0       0       0
# GC                    0       0       0       0       0       0       0
# GEN                   0       0       0       0       0       0       0
# GG                    0       0       0       0       0       0       0
# N64                   0       0       0       0       0       0       0
# NES                   0       0       0       6      13      11      19
# NG                    0       0       0       0       0       0       0
# PC                    0       0       0       0       0       1       0
# PCFX                  0       0       0       0       0       0       0
# PS                    0       0       0       0       0       0       0
# PS2                   0       0       0       0       0       0       0
# PS3                   0       0       0       0       0       0       0
# PS4                   0       0       0       0       0       0       0
# PSP                   0       0       0       0       0       0       0
# PSV                   0       0       0       0       0       0       0
# SAT                   0       0       0       0       0       0       0
# SCD                   0       0       0       0       0       0       0
# SNES                  0       0       0       0       0       0       0
# TG16                  0       0       0       0       0       0       0
# WS                    0       0       0       0       0       0       0
# Wii                   0       0       0       0       0       0       0
# WiiU                  0       0       0       0       0       0       0
# X360                  0       0       0       0       0       0       0
# XB                    0       0       0       0       0       0       0
# XOne                  0       0       0       0       0       0       0
#
# Year_of_Release  1987.0  1988.0  1989.0  ...  2010.0  2011.0  2012.0  2013.0  \
# Platform                                 ...
# 2600                  6       2       2  ...       0       0       0       0
# 3DO                   0       0       0  ...       0       0       0       0
# 3DS                   0       0       0  ...       0     116      93      91
# DC                    0       0       0  ...       0       0       0       0
# DS                    0       0       0  ...     323     153      23       8
# GB                    0       1      10  ...       0       0       0       0
# GBA                   0       0       0  ...       0       0       0       0
# GC                    0       0       0  ...       0       0       0       0
# GEN                   0       0       0  ...       0       0       0       0
# GG                    0       0       0  ...       0       0       0       0
# N64                   0       0       0  ...       0       0       0       0
# NES                  10      11       5  ...       0       0       0       0
# NG                    0       0       0  ...       0       0       0       0
# PC                    0       1       0  ...      90     139      61      38
# PCFX                  0       0       0  ...       0       0       0       0
# PS                    0       0       0  ...       0       0       0       0
# PS2                   0       0       0  ...      38       7       0       0
# PS3                   0       0       0  ...     181     215     148     126
# PS4                   0       0       0  ...       0       0       0      16
# PSP                   0       0       0  ...     188     139     106      54
# PSV                   0       0       0  ...       0      18      53      63
# SAT                   0       0       0  ...       0       0       0       0
# SCD                   0       0       0  ...       0       0       0       0
# SNES                  0       0       0  ...       0       0       0       0
# TG16                  0       0       0  ...       0       0       0       0
# WS                    0       0       0  ...       0       0       0       0
# Wii                   0       0       0  ...     253     143      31      12
# WiiU                  0       0       0  ...       0       0      32      42
# X360                  0       0       0  ...     182     206     106      75
# XB                    0       0       0  ...       0       0       0       0
# XOne                  0       0       0  ...       0       0       0      19
#
# Year_of_Release  2014.0  2015.0  2016.0  2017.0  2020.0  Total
# Platform
# 2600                  0       0       0       0       0    348
# 3DO                   0       0       0       0       0      9
# 3DS                  80      86      46       0       0   1536
# DC                    0       0       0       0       0    156
# DS                    0       0       0       0       1   6366
# GB                    0       0       0       0       0    291
# GBA                   0       0       0       0       0   2433
# GC                    0       0       0       0       0   1626
# GEN                   0       0       0       0       0     87
# GG                    0       0       0       0       0      3
# N64                   0       0       0       0       0    948
# NES                   0       0       0       0       0    294
# NG                    0       0       0       0       0     36
# PC                   47      50      54       0       0   2871
# PCFX                  0       0       0       0       0      3
# PS                    0       0       0       0       0   3570
# PS2                   0       0       0       0       0   6381
# PS3                 108      73      38       0       0   3918
# PS4                  75     137     164       1       0   1179
# PSP                  10       3       0       0       0   3579
# PSV                 100     110      85       2       0   1293
# SAT                   0       0       0       0       0    519
# SCD                   0       0       0       0       0     18
# SNES                  0       0       0       0       0    717
# TG16                  0       0       0       0       0      6
# WS                    0       0       0       0       0     18
# Wii                   6       4       1       0       0   3858
# WiiU                 31      28      14       0       0    441
# X360                 63      35      13       0       0   3696
# XB                    0       0       0       0       0   2409
# XOne                 61      80      87       0       0    741
#
# [31 rows x 40 columns]

# %%
platYear1985 = platYear.copy().iloc[:,15:]
platYear1985.head()
# Out:
# Year_of_Release  1995.0  1996.0  1997.0  1998.0  1999.0  2000.0  2001.0  \
# Platform
# 2600                  0       0       0       0       0       0       0
# 3DO                   2       0       0       0       0       0       0
# 3DS                   0       0       0       0       0       0       0
# DC                    0       0       0       7      14      20       8
# DS                    0       0       0       0       0       0       0
#
# Year_of_Release  2002.0  2003.0  2004.0  ...  2010.0  2011.0  2012.0  2013.0  \
# Platform                                 ...
# 2600                  0       0       0  ...       0       0       0       0
# 3DO                   0       0       0  ...       0       0       0       0
# 3DS                   0       0       0  ...       0     116      93      91
# DC                    1       0       0  ...       0       0       0       0
# DS                    0       0      23  ...     323     153      23       8
#
# Year_of_Release  2014.0  2015.0  2016.0  2017.0  2020.0  Total
# Platform
# 2600                  0       0       0       0       0    116
# 3DO                   0       0       0       0       0      3
# 3DS                  80      86      46       0       0    512
# DC                    0       0       0       0       0     52
# DS                    0       0       0       0       1   2122
#
# [5 rows x 25 columns]

# %%
platYear1985.head()
# Out:
# Year_of_Release  1995.0  1996.0  1997.0  1998.0  1999.0  2000.0  2001.0  \
# Platform
# 2600                  0       0       0       0       0       0       0
# 3DO                   2       0       0       0       0       0       0
# 3DS                   0       0       0       0       0       0       0
# DC                    0       0       0       7      14      20       8
# DS                    0       0       0       0       0       0       0
#
# Year_of_Release  2002.0  2003.0  2004.0  ...  2010.0  2011.0  2012.0  2013.0  \
# Platform                                 ...
# 2600                  0       0       0  ...       0       0       0       0
# 3DO                   0       0       0  ...       0       0       0       0
# 3DS                   0       0       0  ...       0     116      93      91
# DC                    1       0       0  ...       0       0       0       0
# DS                    0       0      23  ...     323     153      23       8
#
# Year_of_Release  2014.0  2015.0  2016.0  2017.0  2020.0  Total
# Platform
# 2600                  0       0       0       0       0    116
# 3DO                   0       0       0       0       0      3
# 3DS                  80      86      46       0       0    512
# DC                    0       0       0       0       0     52
# DS                    0       0       0       0       1   2122
#
# [5 rows x 25 columns]

# %%
platYear1985 = platYear.copy().iloc[:,15:]


popPlatform2 = platYear1985[(platYear1985['Total']>800)].sort_values(by='Total', ascending = False)
neededdata2 = popPlatform2.loc[:,:]
maxi2 = neededdata2.values.max()
mini2 = neededdata2.values.min()
popPlatformfinal2 = popPlatform2.append(pd.DataFrame(popPlatform2.sum(), columns=['total']).T, ignore_index=False)

plt.figure(figsize=(16,8))
sns.heatmap(popPlatformfinal2, vmin = mini2, vmax = maxi2, annot=True, fmt="d")
#plt.xticks(rotation = 90)
plt.show()

# %%
GenreGT = df.groupby(['Genre']).sum().loc[:, 'NA_Sales':'Global_Sales'].T

# %%
GenreGT['Total'] = GenreGT.sum(axis=1)

# %%
GenreGT['Action%'] = GenreGT['Action']/GenreGT['Total']
GenreGT['Adventure%'] = GenreGT['Adventure']/GenreGT['Total']
GenreGT['Fighting%'] = GenreGT['Fighting']/GenreGT['Total']
GenreGT['Misc%'] = GenreGT['Misc']/GenreGT['Total']

GenreGT['Platform%'] = GenreGT['Platform']/GenreGT['Total']
GenreGT['Puzzle%'] = GenreGT['Puzzle']/GenreGT['Total']
GenreGT['Racing%'] = GenreGT['Racing']/GenreGT['Total']
GenreGT['Role-Playing%'] = GenreGT['Role-Playing']/GenreGT['Total']
GenreGT['Shooter%'] = GenreGT['Shooter']/GenreGT['Total']

GenreGT['Simulation%'] = GenreGT['Simulation']/GenreGT['Total']
GenreGT['Sports%'] = GenreGT['Sports']/GenreGT['Total']
GenreGT['Strategy%'] = GenreGT['Strategy']/GenreGT['Total']

# %%
GenreGT
# Out:
# Genre          Action  Adventure  Fighting    Misc  Platform  Puzzle  Racing  \
# NA_Sales       863.17     101.39    220.51  394.01    444.44  121.13  356.86
# EU_Sales       510.99      63.15     99.00  208.55    199.39   49.78  234.48
# JP_Sales       160.14      52.22     87.28  107.02    130.71   56.68   56.63
# Other_Sales    182.22      16.37     35.87   73.00     51.01   12.30   75.51
# Global_Sales  1717.62     233.25    442.63  783.19    825.86  240.33  723.69
#
# Genre         Role-Playing  Shooter  Simulation  ...  Fighting%     Misc%  \
# NA_Sales            330.04   584.83      180.67  ...   0.050856  0.090869
# EU_Sales            188.24   314.52      113.32  ...   0.041292  0.086985
# JP_Sales            353.44    38.68       63.64  ...   0.067624  0.082918
# Other_Sales          59.41   103.33       30.59  ...   0.045837  0.093285
# Global_Sales        930.90  1041.83      388.37  ...   0.050237  0.088889
#
# Genre         Platform%   Puzzle%   Racing%  Role-Playing%  Shooter%  \
# NA_Sales       0.102500  0.027936  0.082302       0.076116  0.134878
# EU_Sales       0.083164  0.020763  0.097800       0.078514  0.131184
# JP_Sales       0.101273  0.043915  0.043876       0.273842  0.029969
# Other_Sales    0.065184  0.015718  0.096492       0.075918  0.132043
# Global_Sales   0.093732  0.027276  0.082136       0.105653  0.118243
#
# Genre         Simulation%   Sports%  Strategy%
# NA_Sales         0.041667  0.154797   0.015625
# EU_Sales         0.047265  0.154880   0.018682
# JP_Sales         0.049308  0.104543   0.038197
# Other_Sales      0.039090  0.168948   0.013712
# Global_Sales     0.044078  0.148724   0.019618
#
# [5 rows x 25 columns]

# %%
GenreG = GenreGT.T

# %%
GenreG['NA_Sales%'] = GenreG['NA_Sales']/GenreG['Global_Sales']
GenreG['EU_Sales%'] = GenreG['EU_Sales']/GenreG['Global_Sales']
GenreG['JP_Sales%'] = GenreG['JP_Sales']/GenreG['Global_Sales']
GenreG['Other_Sales%'] = GenreG['Other_Sales']/GenreG['Global_Sales']

# %%
GenreG.head()
# Out:
#            NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  NA_Sales%  \
# Genre
# Action       863.17    510.99    160.14       182.22       1717.62   0.502538
# Adventure    101.39     63.15     52.22        16.37        233.25   0.434684
# Fighting     220.51     99.00     87.28        35.87        442.63   0.498181
# Misc         394.01    208.55    107.02        73.00        783.19   0.503084
# Platform     444.44    199.39    130.71        51.01        825.86   0.538154
#
#            EU_Sales%  JP_Sales%  Other_Sales%
# Genre
# Action      0.297499   0.093234      0.106089
# Adventure   0.270740   0.223880      0.070182
# Fighting    0.223663   0.197185      0.081038
# Misc        0.266283   0.136646      0.093209
# Platform    0.241433   0.158271      0.061766

# %%
plt.figure(figsize=(14,8))

ax=sns.heatmap(GenreG.loc[:'Total','NA_Sales%':'Other_Sales%'], vmax =1, vmin=0, annot=True, fmt = '.2%',cmap='terrain')

ax.set_xlabel(xlabel='Sales Percentage', fontsize=16)
ax.set_ylabel(ylabel="Genre", fontsize=16)
ax.set_title(label="Percentage of Sales by Genre", fontsize=20)

plt.show()

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(18,6))

ax1.set_title("Total Sales per Region by Genre", fontsize=16)
sns.heatmap(GenreG.loc['Action':'Strategy','NA_Sales':'Other_Sales'], annot=True, fmt = '.1f', ax=ax1, cmap='plasma')

ax2.set_title("Percentage of Sales of each Region by Genre",fontsize=16)

sns.heatmap(GenreG.loc['Action%':'Strategy%','NA_Sales':'Other_Sales'], vmax =1, vmin=0, annot=True, fmt = '.2%', ax=ax2, cmap='plasma')

plt.show()

# %%
plt.figure(figsize=(14,8))

sns.heatmap(GenreG.loc[:'Total','NA_Sales%':'Other_Sales%'], vmax =1, vmin=0, annot=True, fmt = '.2%', cmap='plasma')
plt.show()

# %%
PubGroup = df.groupby(['Publisher']).sum().loc[:, 'NA_Sales':'Global_Sales']
PubGroup['NA_Sales%'] = PubGroup['NA_Sales']/PubGroup['Global_Sales']
PubGroup['EU_Sales%'] = PubGroup['EU_Sales']/PubGroup['Global_Sales']
PubGroup['JP_Sales%'] = PubGroup['JP_Sales']/PubGroup['Global_Sales']
PubGroup['Other_Sales%'] = PubGroup['Other_Sales']/PubGroup['Global_Sales']

# %%
PubGroup = PubGroup.sort_values(by='Global_Sales', ascending = False)

# %%
PubGroup10 = PubGroup[:10]

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(18,7))


ax1.set_title("Comparison of Sales by Top-10 Selling Publishers")
sns.heatmap(PubGroup10.loc[:, 'NA_Sales':'Other_Sales'], annot=True, fmt = '.1f', ax=ax1,cmap='viridis')

ax1.set_xlabel('Sales Region')

ax2.set_title("Comparison of Sales by Top-10 Selling Publishers - %")

sns.heatmap(PubGroup10.loc[:,'NA_Sales%':'Other_Sales%'], vmax =1, vmin=0, annot=True, fmt = '.2%', ax=ax2, cmap='viridis')

ax2.set_xlabel('Sales Region')

plt.show()

# %%
PubGroup.head()
# Out:
#                              NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                       815.86    418.58    457.74        94.55
# Electronic Arts                588.65    370.02     14.29       126.82
# Activision                     428.92    214.10      6.71        75.27
# Sony Computer Entertainment    266.17    186.40     74.15        79.62
# Ubisoft                        252.12    161.72      7.35        49.09
#
#                              Global_Sales  NA_Sales%  EU_Sales%  JP_Sales%  \
# Publisher
# Nintendo                          1786.72   0.456624   0.234273   0.256190
# Electronic Arts                   1100.05   0.535112   0.336367   0.012990
# Activision                         725.14   0.591500   0.295253   0.009253
# Sony Computer Entertainment        606.27   0.439029   0.307454   0.122305
# Ubisoft                            470.45   0.535912   0.343756   0.015623
#
#                              Other_Sales%
# Publisher
# Nintendo                         0.052918
# Electronic Arts                  0.115286
# Activision                       0.103801
# Sony Computer Entertainment      0.131328
# Ubisoft                          0.104347

# %%
PGT = PubGroup.T

# %%
PGT['Total'] = df.sum(axis=1)
PGT.head()
# Out:
# Publisher     Nintendo  Electronic Arts  Activision  \
# NA_Sales        815.86           588.65      428.92
# EU_Sales        418.58           370.02      214.10
# JP_Sales        457.74            14.29        6.71
# Other_Sales      94.55           126.82       75.27
# Global_Sales   1786.72          1100.05      725.14
#
# Publisher     Sony Computer Entertainment  Ubisoft  Take-Two Interactive  \
# NA_Sales                           266.17   252.12                222.92
# EU_Sales                           186.40   161.72                119.06
# JP_Sales                            74.15     7.35                  5.93
# Other_Sales                         79.62    49.09                 55.68
# Global_Sales                       606.27   470.45                403.58
#
# Publisher        THQ  Konami Digital Entertainment    Sega  \
# NA_Sales      207.55                         88.67  107.99
# EU_Sales       93.66                         67.93   80.08
# JP_Sales        5.01                         91.03   56.22
# Other_Sales    31.87                         29.54   23.59
# Global_Sales  338.11                        277.36  268.11
#
# Publisher     Namco Bandai Games  ...  Red Flagship  Piacci  Commseed  \
# NA_Sales                   69.76  ...          0.00    0.00      0.00
# EU_Sales                   42.14  ...          0.00    0.00      0.00
# JP_Sales                  127.62  ...          0.01    0.01      0.01
# Other_Sales                14.55  ...          0.00    0.00      0.00
# Global_Sales              254.19  ...          0.01    0.01      0.01
#
# Publisher     Michaelsoft  Media Entertainment  Ascaron Entertainment  \
# NA_Sales             0.00                 0.00                   0.00
# EU_Sales             0.00                 0.00                   0.01
# JP_Sales             0.01                 0.01                   0.00
# Other_Sales          0.00                 0.00                   0.00
# Global_Sales         0.01                 0.01                   0.01
#
# Publisher     Lighthouse Interactive  Boost On  EON Digital Entertainment  \
# NA_Sales                        0.00      0.00                       0.01
# EU_Sales                        0.01      0.00                       0.00
# JP_Sales                        0.00      0.01                       0.00
# Other_Sales                     0.00      0.00                       0.00
# Global_Sales                    0.01      0.01                       0.01
#
# Publisher     Total
# NA_Sales        NaN
# EU_Sales        NaN
# JP_Sales        NaN
# Other_Sales     NaN
# Global_Sales    NaN
#
# [5 rows x 582 columns]

# %%
PubGroup.loc['Total'] = PubGroup.sum()
PubGroup.head()
# Out:
#                              NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Publisher
# Nintendo                       815.86    418.58    457.74        94.55
# Electronic Arts                588.65    370.02     14.29       126.82
# Activision                     428.92    214.10      6.71        75.27
# Sony Computer Entertainment    266.17    186.40     74.15        79.62
# Ubisoft                        252.12    161.72      7.35        49.09
#
#                              Global_Sales  NA_Sales%  EU_Sales%  JP_Sales%  \
# Publisher
# Nintendo                          1786.72   0.456624   0.234273   0.256190
# Electronic Arts                   1100.05   0.535112   0.336367   0.012990
# Activision                         725.14   0.591500   0.295253   0.009253
# Sony Computer Entertainment        606.27   0.439029   0.307454   0.122305
# Ubisoft                            470.45   0.535912   0.343756   0.015623
#
#                              Other_Sales%
# Publisher
# Nintendo                         0.052918
# Electronic Arts                  0.115286
# Activision                       0.103801
# Sony Computer Entertainment      0.131328
# Ubisoft                          0.104347

# %%
PubGroupPer = PubGroup.copy().T

# %%
PubGroupPer = ((PubGroupPer.loc[:,:].div(PubGroupPer['Total'],axis=0))).T

# %%
PubGroupPer10 = PubGroupPer.copy()[:10]
sns.heatmap(PubGroupPer10.loc[:,'NA_Sales':'Other_Sales'], vmax =1, vmin=0, annot=True, fmt = '.1%', cmap='viridis')



plt.show()

# %%
totals = PubGroup.loc['Total']

# %%
df.columns
# Out:
# Index(['rank', 'Name', 'Platform', 'Year_of_Release', 'Genre', 'Publisher',
#        'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales',
#        'Rating'],
#       dtype='object')

# %%
df['Year_of_Release'] = df['Year_of_Release'].replace(2020, 2009)

# %%
df_y = df.groupby(['Year_of_Release']).sum()
df_y.reset_index(inplace=True)
df_y.head()
# Out:
#    Year_of_Release    rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0             1980   29755     10.59      0.67      0.00         0.12
# 1             1981  189931     33.40      1.96      0.00         0.32
# 2             1982  148806     26.92      1.65      0.00         0.31
# 3             1983   56587      7.76      0.80      8.10         0.14
# 4             1984   22883     33.28      2.10     14.27         0.70
#
#    Global_Sales
# 0         11.38
# 1         35.77
# 2         28.86
# 3         16.79
# 4         50.36

# %%
colors = sns.color_palette("GnBu_d", len(df_y['Year_of_Release']))
plt.figure(figsize=(16,7))
ax = sns.barplot(y = df_y['Global_Sales'], x = df_y['Year_of_Release'], palette=colors)
ax.set_xlabel(xlabel='Year', fontsize=16)
ax.set_xticklabels(labels = df_y['Year_of_Release'], fontsize=12, rotation=50)
ax.set_ylabel(ylabel='$ (Millions)', fontsize=16)
ax.set_title(label='Game Sales in $ Millions Per Year', fontsize=20)
plt.show();

# %%
PubRelease = df.groupby(['Publisher']).count().iloc[:,0]
PubRelease = pd.DataFrame(PubRelease.sort_values(ascending=False))[0:10]
publishers = PubRelease.index
PubRelease.columns = ['Releases']

colors = sns.color_palette("GnBu_d", len(PubRelease))
plt.figure(figsize=(12,8))
ax = sns.barplot(y = publishers , x = 'Releases', data=PubRelease, orient='h', palette=colors)
ax.set_xlabel(xlabel='Number of Releases', fontsize=16)
ax.set_ylabel(ylabel='Publisher', fontsize=16)
ax.set_title(label='Top 10 Publishers by Games Released', fontsize=20)
ax.set_yticklabels(labels = publishers, fontsize=14)
plt.show()

# %%
PubRevenue = df.groupby(['Publisher']).sum()['Global_Sales']
PubRevenue = pd.DataFrame(PubRevenue.sort_values(ascending=False))[0:10]
publishers = PubRevenue.index
PubRevenue.columns = ['Global Sales']

colors = sns.color_palette("Set3", len(PubRevenue))
plt.figure(figsize=(12,8))
ax = sns.barplot(y = publishers , x = 'Global Sales', data=PubRevenue, orient='h', palette=colors)
ax.set_xlabel(xlabel='Revenue in $ Millions', fontsize=16)
ax.set_ylabel(ylabel='Publisher', fontsize=16)
ax.set_title(label='Top 10 Total Publisher Game Revenue', fontsize=20)
ax.set_yticklabels(labels = publishers, fontsize=14)
plt.show();

# %%
Publisher = df.groupby(['Publisher']).count().iloc[:,0]
Publisher = pd.DataFrame(Publisher.sort_values(ascending=False))

Revenue = df.groupby(['Publisher']).sum()['Global_Sales']
Revenue = pd.DataFrame(Revenue.sort_values(ascending=False))

# %%
Pub = Publisher.join(Revenue,how='outer')

# %%
Pub.sort_values(by='rank',ascending=False, inplace=True)
Pub['Avg_Sales'] = Pub['Global_Sales']/Pub['rank']
Pub = (Pub[Pub['rank']>150])
Pub.sort_values(by='Avg_Sales',ascending=False, inplace=True)
Pub
# Out:
#                                         rank  Global_Sales  Avg_Sales
# Publisher
# Nintendo                                 700       1786.72   2.552457
# Microsoft Game Studios                   191        248.32   1.300105
# Take-Two Interactive                     421        403.58   0.958622
# Sony Computer Entertainment              686        606.27   0.883776
# Electronic Arts                         1344       1100.05   0.818490
# Activision                               976        725.14   0.742971
# Warner Bros. Interactive Entertainment   220        140.74   0.639727
# Square Enix                              232        143.91   0.620302
# Disney Interactive Studios               214        116.18   0.542897
# Capcom                                   381        199.08   0.522520
# Ubisoft                                  930        470.45   0.505860
# Eidos Interactive                        196         96.42   0.491939
# THQ                                      712        338.11   0.474874
# Sega                                     631        268.11   0.424897
# Atari                                    351        146.42   0.417151
# Midway Games                             196         69.11   0.352602
# Vivendi Games                            161         56.66   0.351925
# Acclaim Entertainment                    184         64.15   0.348641
# Konami Digital Entertainment             825        277.36   0.336194
# 505 Games                                191         55.32   0.289634
# Namco Bandai Games                       935        254.19   0.271861
# Tecmo Koei                               348         53.54   0.153851
# D3Publisher                              183         23.67   0.129344

# %%
publishers = Pub.index

colors = sns.color_palette("CMRmap", len(Pub.index))
plt.figure(figsize=(12,8))
ax = sns.barplot(y = publishers , x = 'Avg_Sales', data=Pub, orient='h', palette=colors)
ax.set_xlabel(xlabel='Efficiency Factor', fontsize=16)
ax.set_ylabel(ylabel='Publisher', fontsize=16)
ax.set_title(label='Revenue Efficiency (Millions ($) Earned/Games Produced - Min 150 Games Produced)', fontsize=20)
ax.set_yticklabels(labels = publishers, fontsize=14)
plt.show();

# %%
Genre = df.groupby(['Genre']).count().iloc[:,0]
Genre = pd.DataFrame(Genre.sort_values(ascending=False))

RevenueG = df.groupby(['Genre']).sum()['Global_Sales']
RevenueG = pd.DataFrame(RevenueG.sort_values(ascending=False))

GR = Genre.join(RevenueG,how='outer')
GR.sort_values(by='rank',ascending=False, inplace=True)
GR['Avg_Sales'] = GR['Global_Sales']/GR['rank']

# %%
GR = (GR[GR['rank']>150])
GR.sort_values(by='Avg_Sales',ascending=False, inplace=True)
GR
# Out:
#               rank  Global_Sales  Avg_Sales
# Genre
# Platform       878        825.86   0.940615
# Shooter       1296       1041.83   0.803881
# Role-Playing  1483        930.90   0.627714
# Racing        1225        723.69   0.590767
# Sports        2306       1310.39   0.568252
# Fighting       837        442.63   0.528829
# Action        3307       1717.62   0.519389
# Misc          1697        783.19   0.461514
# Simulation     857        388.37   0.453174
# Puzzle         569        240.33   0.422373
# Strategy       673        172.85   0.256835
# Adventure     1291        233.25   0.180674

# %%
publishers = GR.index

colors = sns.color_palette("Set3", len(GR.index))
plt.figure(figsize=(12,8))
ax = sns.barplot(y = publishers , x = 'Avg_Sales', data=GR, orient='h', palette=colors)
ax.set_xlabel(xlabel='Efficiency Factor', fontsize=16)
ax.set_ylabel(ylabel='Genre', fontsize=16)
ax.set_title(label='Genre Revenue Efficiency (Millions ($) Earned/Games Produced)', fontsize=20)
ax.set_yticklabels(labels = publishers, fontsize=14)
plt.show();

# %%
Genre_STD = df.groupby(['Genre']).std()['Global_Sales']
Genre_STD = pd.DataFrame(Genre_STD.sort_values(ascending=False))
Genre_STD = Genre_STD.rename(columns={'Global_Sales':'Global_Sales_STD'})
Genre_STD
# Out:
#               Global_Sales_STD
# Genre
# Platform              2.587494
# Sports                2.099598
# Shooter               1.831543
# Role-Playing          1.718215
# Racing                1.671465
# Puzzle                1.577094
# Misc                  1.321628
# Simulation            1.196802
# Action                1.153706
# Fighting              0.954169
# Strategy              0.522302
# Adventure             0.505795

# %%
GR = GR.join(Genre_STD,how='outer')
GR
# Out:
#               rank  Global_Sales  Avg_Sales  Global_Sales_STD
# Genre
# Action        3307       1717.62   0.519389          1.153706
# Adventure     1291        233.25   0.180674          0.505795
# Fighting       837        442.63   0.528829          0.954169
# Misc          1697        783.19   0.461514          1.321628
# Platform       878        825.86   0.940615          2.587494
# Puzzle         569        240.33   0.422373          1.577094
# Racing        1225        723.69   0.590767          1.671465
# Role-Playing  1483        930.90   0.627714          1.718215
# Shooter       1296       1041.83   0.803881          1.831543
# Simulation     857        388.37   0.453174          1.196802
# Sports        2306       1310.39   0.568252          2.099598
# Strategy       673        172.85   0.256835          0.522302

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(20,5))

publishers = GR.index

colors = sns.color_palette("Set3", len(GR.index))

ax1 = sns.barplot(y = publishers , x = 'Avg_Sales', data=GR, orient='h', palette=colors, ax=ax1)
ax1.set_xlabel(xlabel='Efficiency Factor', fontsize=16)
ax1.set_ylabel(ylabel='Genre', fontsize=16)
ax1.set_title(label='Genre Revenue Efficiency (Millions ($) Earned/Games Produced)', fontsize=20)
ax1.set_yticklabels(labels = publishers, fontsize=14)

ax2 = sns.barplot(y = publishers , x = 'Global_Sales_STD', data=GR, orient='h', palette=colors, ax=ax2)
ax2.set_xlabel(xlabel='Standard Deviation -Sales', fontsize=16)
ax2.set_ylabel(ylabel='Genre', fontsize=16)
ax2.set_title(label='Standard Deviation for Sales by Genre', fontsize=20)
ax2.set_yticklabels(labels = publishers, fontsize=14)


plt.show();

# %%
regions = ['North America','European Union','Japan','Other','Total(Global)']

plt.figure(figsize=(12,8))
ax = sns.pointplot(x=df_y['Year_of_Release'], y=df_y['NA_Sales'], color='b', scale=0.7)
ax = sns.pointplot(x=df_y['Year_of_Release'], y=df_y['EU_Sales'], color='g', scale=0.7)
ax = sns.pointplot(x=df_y['Year_of_Release'], y=df_y['JP_Sales'], color='m', scale=0.7)
ax = sns.pointplot(x=df_y['Year_of_Release'], y=df_y['Other_Sales'], color='y', scale=0.7)
ax = sns.pointplot(x=df_y['Year_of_Release'], y=df_y['Global_Sales'], color='w', scale=0.7)

ax.set_xticklabels(labels=df_y['Year_of_Release'], fontsize=10, rotation=60)
ax.set_xlabel(xlabel='Year', fontsize=16)
ax.set_ylabel(ylabel='Revenue in $ Millions', fontsize=16)
ax.set_title(label='Total Revenue Per Region by Year (in $ Millions)', fontsize=20)
ax.legend(handles=ax.lines[::len(df_y['Year_of_Release'])+1], labels=regions, fontsize=10)
plt.show()

# %%
df_y.head()
# Out:
#    Year_of_Release    rank  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0             1980   29755     10.59      0.67      0.00         0.12
# 1             1981  189931     33.40      1.96      0.00         0.32
# 2             1982  148806     26.92      1.65      0.00         0.31
# 3             1983   56587      7.76      0.80      8.10         0.14
# 4             1984   22883     33.28      2.10     14.27         0.70
#
#    Global_Sales
# 0         11.38
# 1         35.77
# 2         28.86
# 3         16.79
# 4         50.36

# %%
Publishers10 = Pub.head(10)

# %%
df_10 = df[df['Publisher'].isin(Publishers10.index)]
plt.figure(figsize=(16,8))
sns.boxplot(x=df_10['Publisher'], y=df_10['Global_Sales'],data=df_10, palette="Set3")
plt.title(label='Boxplot of Top 10 Publishers', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(16,8))
colors = sns.color_palette("GnBu_d", len(df_10['Publisher']))
ax = sns.boxplot(x=df_10['Publisher'], y=df_10['Global_Sales'],data=df_10, palette='Set3', showfliers=False)
ax.set_ylabel(ylabel='Revenue in $ Millions/Game', fontsize=16)

plt.title(label='Top 10 Grossing Game Developers - Outliers Removed', fontsize=20)
#ax.set_xticklabels(labels = df_10['Publisher'], fontsize=10, rotation=50)

plt.show()

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(15,5))

x3 = df['Global_Sales']
sns.distplot(x3, bins=50, ax=ax1, color='g');

x4 = df['NA_Sales']
sns.distplot(x4, bins=50, ax=ax2, color='m');
   
ax1.set_ylabel('Probability')
ax1.set_xlabel('Value')
ax2.set_xlabel('Value')
# Out:
# Text(0.5, 0, 'Value')

# %%
Q25 = df['Global_Sales'].quantile(0.25)
Q75 = df['Global_Sales'].quantile(0.75)
IQR = Q75-Q25
MaxQ = Q75+1.5*IQR
MinQ = max(Q25-1.5*IQR,0.05)
print(MinQ, MaxQ)
# Out:
# 0.05 1.085

# %%
df_NoO = df[(df['Global_Sales']<MaxQ) & (df['Global_Sales']>MinQ)  ]

# %%
len(df_NoO)
# Out:
# 10766

# %%
fig, [ax1, ax2] = plt.subplots(1,2, figsize=(20,8))

x3 = df_NoO['Global_Sales']
sns.distplot(x3, bins=50, ax=ax1, color='g');

x4 = df_NoO['NA_Sales']
sns.distplot(x4, bins=50, ax=ax2, color='m');
   
ax1.set_ylabel('Games', fontsize=20)
ax1.set_xlabel('Global_Sales', fontsize=20)
ax2.set_xlabel('NA_Sales', fontsize=20)

plt.show()

# %%
plt.figure(figsize=(16,8))
colors = sns.color_palette("GnBu_d", len(df_10['Publisher']))

sns.scatterplot(x='Year_of_Release',y='Global_Sales',data=df_NoO, hue='Genre') #Hue
plt.show()

# %%
df_NoO
# Out:
#         rank                                               Name Platform  \
# 1870    1893                                NASCAR Thunder 2004      PS2
# 1871    1894  SpongeBob SquarePants: Revenge of the Flying D...      PS2
# 1872    1895                               Imagine: Babysitters       DS
# 1873    1896                     Namco Museum Battle Collection      PSP
# 1874    1897                              Fisherman's Bass Club      PS2
# 1875    1898                                  Empire: Total War       PC
# 1876    1899                                   Virtua Fighter 5      PS3
# 1877    1900                                    Dante's Inferno      PS3
# 1878    1901                        Toy Story 3: The Video Game      PS3
# 1879    1902                                              Joust     2600
# 1880    1903                         Tom Clancy's Ghost Recon 2      PS2
# 1881    1904                  Final Fantasy XIV: A Realm Reborn      PS3
# 1882    1905                                    Forza Horizon 3     XOne
# 1883    1906           Disney Infinity 2.0: Marvel Super Heroes     X360
# 1884    1907                              Ready 2 Rumble Boxing       PS
# 1885    1908                     Star Wars: The Force Unleashed      PSP
# 1886    1909                            Dragon Ball Z: Taiketsu      GBA
# 1887    1910                             Disney's Lilo & Stitch      GBA
# 1888    1911                                  Star Fox: Assault       GC
# 1889    1912                 Plants vs. Zombies: Garden Warfare     X360
# 1890    1913                                  The Simpsons Game      PSP
# 1891    1914                                    Doko Demo Issyo       PS
# 1892    1915            LEGO Star Wars II: The Original Trilogy       DS
# 1893    1916                                     Call of Duty 3      PS2
# 1894    1917                                     FIFA Soccer 11      Wii
# 1895    1918                 Imagine: Fashion Designer New York       DS
# 1896    1919                                   Prince of Persia      PS3
# 1897    1920                         Championship Manager 99/00       PC
# 1898    1921                                     Virtua Fighter      SAT
# 1899    1922                         WWE SmackDown vs. Raw 2010      PS2
# ...      ...                                                ...      ...
# 12606  12831                                            Gunbird      SAT
# 12607  12832                              Dream C Club Portable      PSP
# 12608  12833                                  Hail to the Chimp     X360
# 12609  12834                         Tom Clancy's Rainbow Six 3       GC
# 12610  12835                                 Elemental Gearbolt       PS
# 12611  12836                                      Rocket League       PC
# 12612  12837                          Warriors: Legends of Troy     X360
# 12613  12838  Nobunaga's Ambition: Sphere of Influence - Sen...      PS4
# 12614  12839                  WWF Wrestlemania: The Arcade Game       PS
# 12615  12840         Dungeon Explorer: Warriors of Ancient Arts       DS
# 12616  12841           Cabela's Big Game Hunter 2005 Adventures      GBA
# 12617  12842         Mega Man 8 Anniversary Collector's Edition      SAT
# 12618  12843                                           Whiplash       XB
# 12619  12844                                          V-Rally 3      PS2
# 12620  12845                            Pro Yakyuu Famista 2011      3DS
# 12621  12846                                      Impact Racing       PS
# 12622  12847                                      Mirror's Edge       PC
# 12623  12848                                        Titan Quest       PC
# 12624  12849                                     Amazing Island       GC
# 12625  12850                                       Space Chimps       DS
# 12626  12851                                           SeaBlade       XB
# 12627  12852      Jikkyou Powerful Pro Yakyuu DreamCast Edition       DC
# 12628  12853    Carmen Sandiego: The Secret of the Stolen Drums      PS2
# 12629  12854              Izuna 2: The Unemployed Ninja Returns       DS
# 12630  12855    Tokyo Mono Harashi: Karasu no Mori Gakuen Kitan      PSP
# 12631  12856                                  Saki: Zenkoku-hen      PSV
# 12632  12857                          Point Blank DS (US sales)       DS
# 12633  12858                               Ski Region Simulator       PC
# 12634  12859                 MotoGP 4 - Official Game of MotoGP      PS2
# 12635  12860                                           Gothic 3       PC
#
#        Year_of_Release         Genre                     Publisher  NA_Sales  \
# 1870              2003        Racing               Electronic Arts      0.53
# 1871              2002      Platform                           THQ      0.53
# 1872              2008    Simulation                       Ubisoft      0.63
# 1873              2005          Misc   Sony Computer Entertainment      0.75
# 1874              2002        Sports                        Agetec      0.53
# 1875              2009      Strategy                          Sega      0.01
# 1876              2007      Fighting                          Sega      0.29
# 1877              2010        Action               Electronic Arts      0.64
# 1878              2010        Action    Disney Interactive Studios      0.51
# 1879              1982      Platform                         Atari      1.01
# 1880              2004       Shooter                       Ubisoft      0.64
# 1881              2013  Role-Playing                   Square Enix      0.37
# 1882              2016        Racing        Microsoft Game Studios      0.42
# 1883              2014        Action    Disney Interactive Studios      0.64
# 1884              1998        Sports                  Midway Games      0.60
# 1885              2008        Action                     LucasArts      0.43
# 1886              2003      Fighting                         Atari      0.77
# 1887              2002      Platform                       Ubisoft      0.77
# 1888              2005       Shooter                      Nintendo      0.68
# 1889              2014       Shooter               Electronic Arts      0.51
# 1890              2007        Action               Electronic Arts      0.24
# 1891              1999          Misc   Sony Computer Entertainment      0.00
# 1892              2006        Action                     LucasArts      0.96
# 1893              2006       Shooter                    Activision      0.89
# 1894              2010        Sports               Electronic Arts      0.26
# 1895              2008    Simulation                       Ubisoft      0.65
# 1896              2008        Action                       Ubisoft      0.47
# 1897              1999        Sports             Eidos Interactive      0.00
# 1898              1994      Fighting                          Sega      0.17
# 1899              2009      Fighting                           THQ      0.53
# ...                ...           ...                           ...       ...
# 12606             1995       Shooter                         Atlus      0.00
# 12607             2010    Simulation                   D3Publisher      0.00
# 12608             2008          Misc                      Gamecock      0.05
# 12609             2004       Shooter                       Ubisoft      0.04
# 12610             1997       Shooter   Sony Computer Entertainment      0.03
# 12611             2016        Sports                     505 Games      0.01
# 12612             2011        Action                    Tecmo Koei      0.00
# 12613             2016          Misc                    Tecmo Koei      0.01
# 12614             1995      Fighting         Acclaim Entertainment      0.03
# 12615             2007  Role-Playing             Rising Star Games      0.05
# 12616             2004        Sports                    Activision      0.04
# 12617             1997      Platform                        Capcom      0.00
# 12618             2003        Racing             Eidos Interactive      0.04
# 12619             2002        Racing                         Atari      0.03
# 12620             2011        Sports            Namco Bandai Games      0.00
# 12621             1996        Racing                           JVC      0.03
# 12622             2009      Platform               Electronic Arts      0.00
# 12623             2006  Role-Playing                           THQ      0.01
# 12624             2004      Strategy                          Sega      0.04
# 12625             2008      Platform           Brash Entertainment      0.05
# 12626             2002       Shooter                TDK Mediactive      0.04
# 12627             2000        Sports  Konami Digital Entertainment      0.00
# 12628             2004        Action            BAM! Entertainment      0.03
# 12629             2007  Role-Playing                       Success      0.05
# 12630             2010  Role-Playing                         Atlus      0.00
# 12631             2015          Misc                   Kaga Create      0.00
# 12632             2006       Shooter                         Atari      0.05
# 12633             2011    Simulation          Excalibur Publishing      0.00
# 12634             2005        Racing   Sony Computer Entertainment      0.03
# 12635             2006  Role-Playing            JoWood Productions      0.00
#
#        EU_Sales  JP_Sales  Other_Sales  Global_Sales Rating
# 1870       0.41      0.00         0.14          1.08      E
# 1871       0.41      0.00         0.14          1.08      E
# 1872       0.35      0.00         0.10          1.08      E
# 1873       0.18      0.00         0.16          1.08   E10+
# 1874       0.41      0.00         0.14          1.08      E
# 1875       0.97      0.00         0.10          1.08      T
# 1876       0.51      0.08         0.20          1.08      T
# 1877       0.28      0.04         0.13          1.08      M
# 1878       0.40      0.00         0.16          1.08      U
# 1879       0.06      0.00         0.01          1.08      U
# 1880       0.34      0.00         0.10          1.08      T
# 1881       0.30      0.28         0.13          1.08      U
# 1882       0.58      0.00         0.08          1.08      E
# 1883       0.34      0.00         0.10          1.08      U
# 1884       0.41      0.00         0.07          1.08      U
# 1885       0.40      0.00         0.24          1.08      T
# 1886       0.29      0.00         0.02          1.08      T
# 1887       0.29      0.00         0.02          1.08      U
# 1888       0.18      0.19         0.03          1.08      T
# 1889       0.47      0.00         0.09          1.08   E10+
# 1890       0.54      0.00         0.30          1.07      T
# 1891       0.00      1.00         0.07          1.07      U
# 1892       0.03      0.00         0.08          1.07      E
# 1893       0.03      0.00         0.15          1.07      T
# 1894       0.69      0.00         0.12          1.07      E
# 1895       0.32      0.00         0.10          1.07      E
# 1896       0.40      0.03         0.17          1.07      T
# 1897       0.98      0.00         0.09          1.07      U
# 1898       0.12      0.77         0.02          1.07      U
# 1899       0.01      0.00         0.54          1.07      T
# ...         ...       ...          ...           ...    ...
# 12606      0.00      0.06         0.00          0.06      U
# 12607      0.00      0.06         0.00          0.06      U
# 12608      0.00      0.00         0.00          0.06      T
# 12609      0.01      0.00         0.00          0.06      M
# 12610      0.02      0.00         0.00          0.06      T
# 12611      0.04      0.00         0.00          0.06      E
# 12612      0.04      0.01         0.01          0.06      U
# 12613      0.00      0.05         0.00          0.06      U
# 12614      0.02      0.00         0.00          0.06      U
# 12615      0.00      0.00         0.00          0.06   E10+
# 12616      0.01      0.00         0.00          0.06      U
# 12617      0.00      0.06         0.00          0.06      U
# 12618      0.01      0.00         0.00          0.06      T
# 12619      0.02      0.00         0.01          0.06      E
# 12620      0.00      0.06         0.00          0.06      U
# 12621      0.02      0.00         0.00          0.06      U
# 12622      0.05      0.00         0.01          0.06      T
# 12623      0.04      0.00         0.01          0.06      T
# 12624      0.01      0.00         0.00          0.06      E
# 12625      0.00      0.00         0.00          0.06      E
# 12626      0.01      0.00         0.00          0.06      T
# 12627      0.00      0.06         0.00          0.06      U
# 12628      0.02      0.00         0.01          0.06      E
# 12629      0.00      0.00         0.00          0.06      T
# 12630      0.00      0.06         0.00          0.06      U
# 12631      0.00      0.06         0.00          0.06      U
# 12632      0.00      0.00         0.00          0.06      U
# 12633      0.05      0.00         0.01          0.06      U
# 12634      0.02      0.00         0.01          0.06      U
# 12635      0.05      0.00         0.01          0.06      T
#
# [10766 rows x 12 columns]

# %% [markdown]
# # Ratings

# %%
df['Rating'].value_counts()
# Out:
# U       6650
# E       3922
# T       2905
# M       1536
# E10+    1393
# EC         8
# K-A        3
# RP         1
# AO         1
# Name: Rating, dtype: int64

# %%
df['Rating'] = df['Rating'].replace('E10+','E')
df['Rating'] = df['Rating'].replace('K-A','E')
df['Rating'] = df['Rating'].replace('AO','M')
df['Rating'] = df['Rating'].replace('RP','E')
df['Rating'] = df['Rating'].replace('EC','E')

# %%
df['Rating'].value_counts()
# Out:
# U    6650
# E    5327
# T    2905
# M    1537
# Name: Rating, dtype: int64

# %%
df_r = df.copy()[df['Rating']!='U']

# %%
df_r.describe()
# Out:
#                rank  Year_of_Release     NA_Sales     EU_Sales     JP_Sales  \
# count   9769.000000      9769.000000  9769.000000  9769.000000  9769.000000
# mean    7561.213840      2007.581841     0.318953     0.183236     0.046463
# std     4627.606887         4.099635     0.826094     0.587466     0.242862
# min        1.000000      1985.000000     0.000000     0.000000     0.000000
# 25%     3544.000000      2004.000000     0.050000     0.010000     0.000000
# 50%     7341.000000      2008.000000     0.120000     0.040000     0.000000
# 75%    11324.000000      2010.000000     0.300000     0.150000     0.000000
# max    16711.000000      2016.000000    41.360000    28.960000     6.500000
#
#        Other_Sales  Global_Sales
# count  9769.000000   9769.000000
# mean      0.064774      0.613674
# std       0.230036      1.674504
# min       0.000000      0.010000
# 25%       0.010000      0.080000
# 50%       0.020000      0.210000
# 75%       0.050000      0.570000
# max      10.570000     82.530000

# %%
fig, [ax1, ax2, ax3] = plt.subplots(1,3, figsize=(28,8))

colors = sns.color_palette("Set2")

ratings = R_S.index

ax1 = sns.barplot(y = ratings , x = 'rank', data=R_S, orient='h', palette=colors, ax=ax1)
ax1.set_xlabel(xlabel='Number of Gamed Produced', fontsize=16)
ax1.set_ylabel(ylabel='ESRB Rating', fontsize=16)
ax1.set_title(label='Total Number of Games by Rating', fontsize=18)
ax1.set_yticklabels(labels = ratings, fontsize=14)



ax2 = sns.barplot(y = ratings , x = 'Global_Sales', data=R_S, orient='h', palette=colors, ax=ax2)
ax2.set_xlabel(xlabel='Revenue in $ Millions', fontsize=16)
ax2.set_ylabel(ylabel='ESRB Rating', fontsize=16)
ax2.set_title(label='Total Game Revenue by ESRB Rating', fontsize=18)
ax2.set_yticklabels(labels = ratings, fontsize=14)



colors = sns.color_palette("Set3")
plt.figure(figsize=(12,8))
ax3 = sns.barplot(y = ratings , x = 'Avg_Sales', data=R_S, orient='h', palette=colors, ax=ax3)
ax3.set_xlabel(xlabel='Efficiency Ratio', fontsize=16)
ax3.set_ylabel(ylabel='Genre', fontsize=16)
ax3.set_title(label='Rating Revenue Efficiency (Millions ($) Earned/Games Produced)', fontsize=18)
ax3.set_yticklabels(labels = ratings, fontsize=14)



plt.show()

# %%
dfRating = df_r.groupby(['Rating']).count().iloc[:,0]
dfRating = pd.DataFrame(dfRating.sort_values(ascending=False))

Rg = df_r.groupby(['Rating']).sum()['Global_Sales']
RS = pd.DataFrame(Rg.sort_values(ascending=False))

R_S = dfRating.join(RS,how='outer')
R_S.sort_values(by='rank',ascending=False, inplace=True)
R_S['Avg_Sales'] = R_S['Global_Sales']/R_S['rank']

# %%
R_S
# Out:
#         rank  Global_Sales  Avg_Sales
# Rating
# E       5327       3056.30   0.573738
# T       2905       1474.13   0.507446
# M       1537       1464.55   0.952863
